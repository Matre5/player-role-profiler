# %%
import pandas as pd
import requests
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
Standard_url = "https://fbref.com/en/comps/9/2024-2025/stats/2024-2025-Premier-League-Stats#all_stats_standard"

data = requests.get(Standard_url)

if data.status_code == 200:
    print("Successfully retrieved page")
else:
    print(f"Failed to retrieve page. Status code: {data.status_code}")
# Out:
# Failed to retrieve page. Status code: 403
